# %% [markdown]
# https://www.consoleroms.com/roms/ps2

# %%
import pandas as pd
# !pip install beautifulsoup4
import bs4
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.consoleroms.com/roms/ps2'

# %%
b = requests.get(url)
b
# Out:
# <Response [200]>

# %%
type(b.text)
# Out:
# str

# %%
a = BeautifulSoup(b.text)
type(a)
# Out:
# bs4.BeautifulSoup

# %%
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    PS2 ROMs Download - Free Sony PlayStation 2 Games - ConsoleRoms
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=1.0" name="viewport"/>
#   <meta content="Download unlimited Sony PlayStation 2 ROMs for free only at ConsoleRoms. Variety of PS2 games that can be played on both computer or phone." name="description"/>
#   <meta content="Global" name="distribution"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/css/style.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/bootstrap-grid.min.css" rel="stylesheet" type="text/css"/>
# ...

# %%
a.find('div',{'class':'centarce'}).text
# Out:
# '95154 Downloads'

# %%
field = a.find_all('div',{'class':'centarce'})
dowloads = [i.text for i in field]
print(dowloads)
print(len(dowloads))
# Out:
# ['95154 Downloads', '83725 Downloads', '82447 Downloads', '49018 Downloads', '42880 Downloads', '34196 Downloads', '33972 Downloads', '33696 Downloads', '32579 Downloads', '31820 Downloads', '31396 Downloads', '29345 Downloads', '28522 Downloads', '27695 Downloads', '24743 Downloads', '24227 Downloads']
# 16

# %%
a.find('span',{'class':'zelena'}).text
# Out:
# '100%'

# %%
field2 = a.find_all('span',{'class':'zelena'})
rating= [i.text for i in field2]
print(rating)
print(len(rating))
# Out:
# ['100%', '98%', '66%', '99%', '99%', '100%', '99%', '100%', '102%']
# 9

# %%
# x=a.find_all('div',{'class':'infoBox'}).text
import re
# matches = re.findall(r'\n(.*?)\n', x)
# matches

# %%
#<div class="clearfix">
# a.find_all('div',{'class':'tagBtns'})
# Field2= [i.text for i in b]
# specifications = [item.replace('\n', ' ').strip() for item in Field2]

# # Printing the cleaned data
print(specifications)
print(len(specifications))

# Assuming 'a' is a BeautifulSoup object and you're finding all divs with class 'tagBtns'
b = a.find_all('div', {'class': 'tagBtns'})

# Extract text from each BeautifulSoup object in the list 'b'
Field2 = [i.get_text() for i in b]

# Clean the extracted text
specifications = [item.replace('\n', ' ').strip() for item in Field2]
# Out:
# ['PS2 Fighting Battle', 'PS2', 'PS2', 'PS2', 'PS2 Racing Driving', 'PS2 Soccer Action', 'PS2 Adventure Action', 'PS2 Racing Driving Action', 'PS2 Fighting Battle', 'PS2 Shooter Action Adventure', 'PS2 Adventure Action', 'PS2 Adventure Action', 'PS2 Fighting Battle', 'PS2', 'PS2 Adventure Action', 'PS2 Adventure Action']
# 16

# %%
x=a.find_all('div',{'class':'infoBox'})
Field2= [i.text for i in x]

game_titles = [re.search(r'\n(.*?)\n', item).group(1) for item in Field2]
print(game_titles)
print(len(game_titles))
# Out:
# ['Dragon Ball Z - Budokai Tenkaichi 3', 'God of War', 'God of War II', 'Resident Evil 4', 'Need For Speed - Underground', 'PES 2013 - Pro Evolution Soccer', 'Spider-Man 3', 'Grand Theft Auto III', 'Mortal Kombat - Deception', 'Call Of Duty 3', 'Simpsons, The - Hit & Run', 'Def Jam - Fight For NY', 'Naruto Shippuden - Ultimate Ninja 5 (E)', 'Gran Turismo 4', 'Bully', 'Crash Bandicoot - The Wrath Of Cortex']
# 16

# %%
data = pd.DataFrame({'Game Title':game_titles,
                    'Specifications':specifications,
                    'Rating':rating,
                    'Dowloads':dowloads,})

data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-2a7f4e0d09dc> in <cell line: 1>()
# ----> 1 data = pd.DataFrame({'Game Title':game_titles,
#       2                     'Specifications':specifications,
#       3                     'Rating':rating,
#       4                     'Dowloads':dowloads,})
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     731         elif isinstance(data, dict):
#     732             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734         elif isinstance(data, ma.MaskedArray):
#     735             from numpy.ma import mrecords
#
# ...

# %%
# prompt: download  data

from google.colab import files
data.to_csv('ps2_games.csv', index = False)
files.download('ps2_games.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-964b40ed356f> in <cell line: 4>()
#       2
#       3 from google.colab import files
# ----> 4 data.to_csv('ps2_games.csv', index = False)
#       5 files.download('ps2_games.csv')
#
# NameError: name 'data' is not defined

# %%
import os

# Define the directory path
directory = 'desktop/project'

# Create the directory if it does not exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the file to the created directory
file_path = os.path.join(directory, 'dataset.xlsx')
df.to_excel(file_path, index=False)

# %%
from IPython.display import clear_output
import time,random

# %%
dowloads=[]; specifications=[]; game_titles=[];

for i in range(1,6):
    base_url = f"https://www.consoleroms.com/roms/ps2/page/{i}"
    print(f'Scraping from page{i}')

    clear_output(wait=True)
    time.sleep(3)

    d = requests.get(base_url)
    soup = BeautifulSoup(d.text,'html')

    d = soup.find_all('div',{'class':'centarce'})
    for i in d:
        i=i.text
        dowloads.append(i)

    field2 = a.find_all('span',{'class':'zelena'})
    for i in field2:
        rating.append(i.text)


    b = a.find_all('div',{'class':'tagBtns'})
    for element in b:
        text = element.text.replace('\n', ' ').strip()
        specifications.append(text)

    x=soup.find_all('div',{'class':'infoBox'})
    for element in x:
        match = re.search(r'\n(.*?)\n', element.text)
        if match:
            game_titles.append(match.group(1).strip())
# Out:
# Scraping from page5

# %%
print(len(game_titles))
print(len(specifications))
print(len(dowloads))
print(len(rating))
# Out:
# 76
# 80
# 76
# 54

# %%
i = len(game_titles)
for k in range(i,81):
    game_titles.append('None')

i = len(dowloads)
for k in range(i,81):
    dowloads.append('None')

i = len(specifications)
for k in range(i,81):
    specifications.append('None')

i = len(rating)
for k in range(i,81):
    rating.append('None')

# %%
data = pd.DataFrame({'Game Title':game_titles,
                    'Specifications':specifications,
                    'Rating':rating,
                    'Dowloads':dowloads,})
data
# Out:
#                              Game Title        Specifications Rating  \
# 0   Dragon Ball Z - Budokai Tenkaichi 3   PS2 Fighting Battle   100%
# 1                            God of War                   PS2    98%
# 2                         God of War II                   PS2    66%
# 3                       Resident Evil 4                   PS2    99%
# 4          Need For Speed - Underground    PS2 Racing Driving    99%
# ..                                  ...                   ...    ...
# 76                                 None   PS2 Fighting Battle   None
# 77                                 None                   PS2   None
# 78                                 None  PS2 Adventure Action   None
# 79                                 None  PS2 Adventure Action   None
# 80                                 None                  None   None
#
#            Dowloads
# 0   95154 Downloads
# 1   83725 Downloads
# 2   82447 Downloads
# 3   49019 Downloads
# 4   42881 Downloads
# ...

# %%
# prompt: download the data dataset

data.to_csv('ps2_games.csv', index = False)
files.download('ps2_games.csv')

# %%
data.isnull().sum()
# Out:
# Game Title        0
# Specifications    0
# Rating            0
# Dowloads          0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Game Title      81 non-null     object
#  1   Specifications  81 non-null     object
#  2   Rating          81 non-null     object
#  3   Dowloads        81 non-null     object
# dtypes: object(4)
# memory usage: 2.7+ KB

# %%
data['Game Title'].unique()
# Out:
# array(['Dragon Ball Z - Budokai Tenkaichi 3', 'God of War',
#        'God of War II', 'Resident Evil 4', 'Need For Speed - Underground',
#        'PES 2013 - Pro Evolution Soccer', 'Spider-Man 3',
#        'Grand Theft Auto III', 'Mortal Kombat - Deception',
#        'Call Of Duty 3', 'Simpsons, The - Hit & Run',
#        'Def Jam - Fight For NY',
#        'Naruto Shippuden - Ultimate Ninja 5 (E)', 'Gran Turismo 4',
#        'Bully', 'Crash Bandicoot - The Wrath Of Cortex',
#        'Downhill Domination', 'WWE SmackDown Shut Your Mouth',
#        'FIFA 13 (E)', 'Black', 'Dragon Ball Z - Budokai 3',
#        'Shadow Of The Colossus', 'Grand Theft Auto - Vice City Stories',
#        'Shadow The Hedgehog', 'Tekken Tag Tournament', 'FIFA Street 2',
#        'Marvel VS. Capcom 2 - New Age of Heroes',
#        'God of War II (Europe, Australia)', 'God Hand',
#        'Mortal Kombat - Armageddon - Premium Edition', 'Silent Hill 2',
#        'Rumble Racing', 'Crash Twinsanity',
# ...

# %%
data['Rating'].nunique()
# Out:
# 6

# %%
# !pip install plotly

# %%
import plotly

# %%
data.columns
# Out:
# Index(['Game Title', 'Specifications', 'Rating', 'Dowloads'], dtype='object')

# %%
import plotly.express as px

# %%
px.box(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(data,animation_frame='Rating')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
colors = ['red','blue','green','orange','pink','violet','yellow','magenta']
fig = go.Figure()

# %%
for i, col in enumerate(data.columns):
    fig.add_trace(go.Box(y=data[col], name=col, marker_color=colors[i]))
fig.update_layout(title="Box Plot", yaxis_title="Value",
                  xaxis_title="Variable")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(data,x='Rating',color_discrete_sequence=['red'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(data,names='Specifications',title="Specifications of Game")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(data, x='Dowloads', nbins=20, title='Specifications of Game')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# data['Game Title'] = data['Game Title'].astype('int64')
# data['Specifications'] = data['Specifications'].astype('int64')
# data['Rating'] = data['Rating'].astype('int64')
# data['Dowloads'] = data['Dowloads'].astype('int64')
# data.info()

# %%
#CHecking the Outliers -->they effect the Modelling part
#First we will calculate the Interquartile range and findout
#Q1,Q3 values then we will cal both lower bound & upper bound

def remove_outliers(df,threshold=3):
    """Remove Outliers"""
    #createa copy of the dataframe
    df_cleaned = df.copy()
    #First based on the threshold value
    #The threshold value determines how far
    #from the first and third quartiles a data point must be to be considered an outlier
    for col in df_cleaned.select_dtypes(include=['int64',
                                                 'float64']).columns:
        Q1 = df_cleaned[col].quantile(0.25) #25th percentile
        Q3 = df_cleaned[col].quantile(0.75) #75th percentile
        IQR = Q3 - Q1 #InterQuantile Range
        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR
        #once the lower bound and upper bound is calculated outliers are found
        df_cleaned = df_cleaned[
            (df_cleaned[col] >= lower_bound) &
            (df_cleaned[col] <= upper_bound)
        ]
    return df_cleaned #it returns a new dataframe

# %%
final_df = remove_outliers(data)
final_df
# Out:
#                              Game Title        Specifications Rating  \
# 0   Dragon Ball Z - Budokai Tenkaichi 3   PS2 Fighting Battle   100%
# 1                            God of War                   PS2    98%
# 2                         God of War II                   PS2    66%
# 3                       Resident Evil 4                   PS2    99%
# 4          Need For Speed - Underground    PS2 Racing Driving    99%
# ..                                  ...                   ...    ...
# 76                                 None   PS2 Fighting Battle   None
# 77                                 None                   PS2   None
# 78                                 None  PS2 Adventure Action   None
# 79                                 None  PS2 Adventure Action   None
# 80                                 None                  None   None
#
#            Dowloads
# 0   95154 Downloads
# 1   83725 Downloads
# 2   82447 Downloads
# 3   49019 Downloads
# 4   42881 Downloads
# ...

# %%
x = final_df.drop(['Specifications', 'Rating'], axis=1)
y = final_df['Game Title']

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# Preprocess the data
data = data.replace('None', pd.NA).dropna()
data.columns = data.columns.str.strip()

# Convert 'Rating' to a numeric value
data['Rating'] = data['Rating'].astype(str).str.rstrip('%').astype(float) / 100.0

# Process 'Downloads' column
downloads_column = 'Dowloads'  # Corrected typo
data[downloads_column] = data[downloads_column].astype(str).str.replace(' Dowloads', '', regex=False)
data[downloads_column] = pd.to_numeric(data[downloads_column], errors='coerce')
data = data.dropna(subset=[downloads_column])
data[downloads_column] = data[downloads_column].astype(int)

# Convert 'Specifications' to numeric if it is categorical
# If 'Specifications' contains categories or strings, use Label Encoding
if data['Specifications'].dtype == 'object':
    le = LabelEncoder()
    data['Specifications'] = le.fit_transform(data['Specifications'])

# Define features and target
X = data[['Game Title', 'Rating', downloads_column]]
y = data['Specifications']

# Print column names to debug
print("Feature Columns:", X.columns)

# Define preprocessing for the features
preprocessor = ColumnTransformer(
    transformers=[
        ('game_title', OneHotEncoder(handle_unknown='ignore'), ['Game Title']),
        ('scaler', StandardScaler(), ['Rating', downloads_column])
    ])

# Create the pipeline
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train the model
pipeline.fit(x_train, y_train)

# Predict and evaluate
y_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Feature Columns: Index(['Game Title', 'Rating', 'Dowloads'], dtype='object')
# Mean Squared Error: 2.872690735063049

# %%
print(len(x_train))
print(len(x_test))
# Out:
# 40
# 14

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

r2 = r2_score(y_test, y_pred)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 2.872690735063049
# R^2 Score: -0.13289212086993474

# %%
data['Game Title']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 0 to 53
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Game Title      54 non-null     object
#  1   Specifications  54 non-null     int64
#  2   Rating          54 non-null     float64
#  3   Dowloads        54 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
Rating = int(input('Enter Rating :'))
Specifications = (input('Enter no of Specifications:'))
Dowloads = int(input('Enter Downloads:'))
# Out:
# Enter Rating :808
# Enter no of Specifications:PS2
# Enter Downloads:18524

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming X and y are already defined

# Define the preprocessor (example setup; adjust as needed)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['Rating', 'Dowloads'])
        # Add other transformers if needed
    ]
)

# Create and train the model
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('poly', PolynomialFeatures(degree=3, include_bias=False)),
    ('model', LinearRegression())
])

# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train the model
pipeline.fit(x_train, y_train)

# Example data for prediction (adjust column names and values as necessary)
example_data = pd.DataFrame({
    'Rating': [0.75],
    'Dowloads': [50000]
})

# Predict using the fitted model
y_pred = pipeline.predict(example_data)

# Print prediction
print("Prediction:", y_pred)

# Evaluate the model
y_test_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R²) Score:", r2)
# Out:
# Prediction: [3.0129307e+27]
# Mean Squared Error (MSE): 5.731323408622236
# R-squared (R²) Score: -1.2602402174848253
